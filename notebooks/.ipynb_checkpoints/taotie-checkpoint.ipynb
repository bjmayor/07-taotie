# %%
import pandas as pd

# %%
df = pd.read_parquet('../assets/sample.parquet')

# %%
df.head()
# Out:
#                              email                                     name  \
# 0   b'rickie.6cl60vv5@example.net'  b'\xe5\xbd\xad\xe6\x9d\xb0\xe8\xa3\x95'
# 1     b'olaf.14ymhjtf@example.org'  b'\xe9\xad\x8f\xe7\x92\x87\xe7\x9b\x88'
# 2  b'rebecca.3a623w6u@example.com'  b'\xe7\x86\x8a\xe7\x95\x85\xe7\x91\x9e'
# 3   b'yvonne.qx06kzs6@example.org'  b'\xe5\xad\x9f\xe7\x91\x9c\xe6\x98\x95'
# 4   b'juston.apls64ti@example.org'  b'\xe9\x92\xb1\xe6\x9d\x89\xe6\x99\x96'
#
#        gender                       created_at  \
# 0  b'unknown' 2020-08-10 13:01:25.925310+00:00
# 1  b'unknown' 2021-11-13 13:00:25.903489+00:00
# 2  b'unknown' 2020-03-27 01:20:25.909394+00:00
# 3  b'unknown' 2022-07-04 00:23:25.871170+00:00
# 4  b'unknown' 2023-11-15 00:40:25.923932+00:00
#
#                    last_visited_at                  last_watched_at  \
# 0 2024-05-04 09:50:25.925310+00:00 2024-04-16 14:54:25.925310+00:00
# 1 2024-04-25 20:57:25.903489+00:00 2024-02-14 23:31:25.903489+00:00
# ...

# %%
df.describe()
# Out:
#                                  email  \
# count                             1000
# unique                            1000
# top     b'rickie.6cl60vv5@example.net'
# freq                                 1
# mean                               NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
#                                            name      gender  \
# count                                      1000        1000
# unique                                      986           1
# top     b'\xe8\xb4\xba\xe6\xad\x86\xe7\xbf\xa0'  b'unknown'
# freq                                          2        1000
# mean                                        NaN         NaN
# min                                         NaN         NaN
# 25%                                         NaN         NaN
# ...

# %%
 df[df['created_at']>'2024-01-01'] # select * from df where created_at > '2024-01-01'
# Out:
#                                   email  \
# 12   b'candelario.k09qbm2w@example.net'
# 26       b'meghan.zfz2xq8m@example.org'
# 221     b'santino.1o3zmd6y@example.com'
# 240    b'theresia.qffrdky6@example.net'
# 265      b'hobart.ny99r96q@example.org'
# 358     b'katrine.ox9xwcox@example.com'
# 378       b'adele.pvfq694y@example.org'
# 380       b'dante.9p35zaj5@example.net'
# 413    b'violette.v4qatmf5@example.net'
# 449   b'granville.lg2rzj02@example.net'
# 463    b'magdalen.4os1hr1k@example.com'
# 470   b'nathaniel.qrw8xacg@example.com'
# 491      b'gaston.ar4k3eld@example.org'
# 581        b'hans.jg8gq4yy@example.org'
# 594       b'haley.m205jnnp@example.net'
# 630       b'vesta.ogpio1y5@example.org'
# 712   b'broderick.nw0o1x33@example.net'
# 807        b'zion.8y2lyoq4@example.org'
# 854     b'stanley.xxeelbo4@example.net'
#
#                                         name      gender  \
# 12   b'\xe5\x91\xa8\xe9\xb8\xbf\xe6\x89\xbf'  b'unknown'
# ...

# %%
df['created_at'].count()
# Out:
# np.int64(1000)

# %%
 df[df['created_at']>'2024-01-01'].count()
# Out:
# email                       19
# name                        19
# gender                      19
# created_at                  19
# last_visited_at             19
# last_watched_at             19
# recent_watched              19
# viewed_but_not_started      19
# started_but_not_finished    19
# finished                    19
# last_email_notification     19
# last_in_app_notification    19
# last_sms_notification       19
# dtype: int64
